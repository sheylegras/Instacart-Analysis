# %% [markdown]
# # Table of Contents
#
# 01. Importing Libraries
# 02. Importing Data
# 03. Exercise Task
# 04. Create Loyalty Flag
# 05. Check Spending Habits
# 06. Create Spending Flag
# 07. Create Order Frequency Flag
# 08. Dealing with Memory Errors
# 09. Extracting Data

# %% [markdown]
# ## 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Importing Data

# %%
#Define path

path = r'C:\Users\legra\Desktop\06-2022 Instacart Basket Analysis'

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared data', 'orders_products_merged_version2.pkl'))

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 21)

# %%
#checking output
df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_previous_order  new_customer  product_id  \
# 0                  8                        NaN          True         196
# 1                  7                       15.0         False         196
# 2                 12                       21.0         False         196
# 3                  7                       29.0         False         196
# 4                 15                       28.0         False         196
#
#    add_to_cart_order  ...  _merge Unnamed: 0  product_name aisle_id  \
# 0                  1  ...    both        195          Soda       77
# 1                  1  ...    both        195          Soda       77
# 2                  1  ...    both        195          Soda       77
# 3                  1  ...    both        195          Soda       77
# 4                  1  ...    both        195          Soda       77
#
#    department_id  prices    price_range_loc     busiest_day    busiest_days  \
# 0              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 1              7     9.0  Mid-range product  Regularly busy    Slowest days
# 2              7     9.0  Mid-range product  Regularly busy    Slowest days
# 3              7     9.0  Mid-range product      Least busy    Slowest days
# 4              7     9.0  Mid-range product      Least busy    Slowest days
#
#   busiest_period_of_day
# 0        Average orders
# 1        Average orders
# 2           Most orders
# 3        Average orders
# 4           Most orders
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 03. Exercise Task

# %%
#Find aggregated mean of order number

df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# The results when using the aggregate function on the entire dataset are different than when we did it on the subset. Some averages are lower while some are higher.

# %% [markdown]
# ## 04. Creating a Loyalty Flag

# %%
#Creating a column for max order

df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#Checking output

df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_previous_order  new_customer  product_id  \
# 0                  8                        NaN          True         196
# 1                  7                       15.0         False         196
# 2                 12                       21.0         False         196
# 3                  7                       29.0         False         196
# 4                 15                       28.0         False         196
#
#    add_to_cart_order  ...  Unnamed: 0 product_name  aisle_id department_id  \
# 0                  1  ...         195         Soda        77             7
# 1                  1  ...         195         Soda        77             7
# 2                  1  ...         195         Soda        77             7
# 3                  1  ...         195         Soda        77             7
# 4                  1  ...         195         Soda        77             7
#
#    prices    price_range_loc     busiest_day    busiest_days  \
# 0     9.0  Mid-range product  Regularly busy  Regularly busy
# 1     9.0  Mid-range product  Regularly busy    Slowest days
# 2     9.0  Mid-range product  Regularly busy    Slowest days
# 3     9.0  Mid-range product      Least busy    Slowest days
# 4     9.0  Mid-range product      Least busy    Slowest days
#
#   busiest_period_of_day max_order
# 0        Average orders        10
# 1        Average orders        10
# 2           Most orders        10
# 3        Average orders        10
# 4           Most orders        10
#
# [5 rows x 22 columns]

# %%
#Creating Flag

df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
#checking flag

df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %% [markdown]
# ## 05. Checking Spending habits

# %%
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# On average loyal customers spend the least for prices of products followed by regular customers and new customers spending the most.

# %% [markdown]
# ## 06. Spender Flag

# %%
#creating avg spent column

df_ords_prods_merge['avg_spent'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_previous_order  new_customer  product_id  \
# 0                  8                        NaN          True         196
# 1                  7                       15.0         False         196
# 2                 12                       21.0         False         196
# 3                  7                       29.0         False         196
# 4                 15                       28.0         False         196
#
#    add_to_cart_order  ...  aisle_id department_id  prices    price_range_loc  \
# 0                  1  ...        77             7     9.0  Mid-range product
# 1                  1  ...        77             7     9.0  Mid-range product
# 2                  1  ...        77             7     9.0  Mid-range product
# 3                  1  ...        77             7     9.0  Mid-range product
# 4                  1  ...        77             7     9.0  Mid-range product
#
#       busiest_day    busiest_days  busiest_period_of_day max_order  \
# 0  Regularly busy  Regularly busy         Average orders        10
# 1  Regularly busy    Slowest days         Average orders        10
# 2  Regularly busy    Slowest days            Most orders        10
# 3      Least busy    Slowest days         Average orders        10
# 4      Least busy    Slowest days            Most orders        10
#
#    loyalty_flag avg_spent
# 0  New customer  6.367797
# 1  New customer  6.367797
# 2  New customer  6.367797
# 3  New customer  6.367797
# 4  New customer  6.367797
#
# [5 rows x 24 columns]

# %%
#Create flag

df_ords_prods_merge.loc[df_ords_prods_merge['avg_spent'] < 10, 'spender_flag'] = 'Low spender'
df_ords_prods_merge.loc[df_ords_prods_merge['avg_spent'] >= 10, 'spender_flag'] = 'High spender'

# %%
#checking output

df_ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spender_flag, dtype: int64

# %% [markdown]
# ## 07. Order Frequency

# %%
#Create order frequency column

df_ords_prods_merge['order_frequency'] = df_ords_prods_merge.groupby(['user_id'])['days_since_previous_order'].transform(np.median)

# %%
df_ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# 13   2715276       15    prior            21                   1
# 14    487368       15    prior            22                   1
#
#     order_hour_of_day  days_since_previous_order  new_customer  product_id  \
# 0                   8                        NaN          True         196
# 1                   7                       15.0         False         196
# 2                  12                       21.0         False         196
# 3                   7                       29.0         False         196
# 4                  15                       28.0         False         196
# 5                   7                       19.0         False         196
# 6                   9                       20.0         False         196
# 7                  14                       14.0         False         196
# 8                  16                        0.0         False         196
# 9                   8                       30.0         False         196
# 10                  9                        7.0         False         196
# 11                 16                        8.0         False         196
# 12                 11                        7.0         False         196
# 13                  9                        7.0         False         196
# 14                 10                       14.0         False         196
#
#     add_to_cart_order  ...  prices    price_range_loc     busiest_day  \
# 0                   1  ...     9.0  Mid-range product  Regularly busy
# 1                   1  ...     9.0  Mid-range product  Regularly busy
# 2                   1  ...     9.0  Mid-range product  Regularly busy
# 3                   1  ...     9.0  Mid-range product      Least busy
# 4                   1  ...     9.0  Mid-range product      Least busy
# 5                   1  ...     9.0  Mid-range product  Regularly busy
# 6                   1  ...     9.0  Mid-range product  Regularly busy
# 7                   2  ...     9.0  Mid-range product  Regularly busy
# 8                   4  ...     9.0  Mid-range product  Regularly busy
# 9                   1  ...     9.0  Mid-range product      Least busy
# 10                  2  ...     9.0  Mid-range product  Regularly busy
# 11                  6  ...     9.0  Mid-range product  Regularly busy
# 12                  1  ...     9.0  Mid-range product  Regularly busy
# 13                  1  ...     9.0  Mid-range product  Regularly busy
# 14                  1  ...     9.0  Mid-range product  Regularly busy
#
#       busiest_days  busiest_period_of_day  max_order      loyalty_flag  \
# 0   Regularly busy         Average orders         10      New customer
# 1     Slowest days         Average orders         10      New customer
# 2     Slowest days            Most orders         10      New customer
# 3     Slowest days         Average orders         10      New customer
# 4     Slowest days            Most orders         10      New customer
# 5   Regularly busy         Average orders         10      New customer
# 6     Busiest days            Most orders         10      New customer
# 7     Busiest days            Most orders         10      New customer
# 8     Busiest days            Most orders         10      New customer
# 9     Slowest days         Average orders         10      New customer
# 10    Busiest days            Most orders         22  Regular customer
# 11  Regularly busy            Most orders         22  Regular customer
# 12  Regularly busy            Most orders         22  Regular customer
# 13    Busiest days            Most orders         22  Regular customer
# 14    Busiest days            Most orders         22  Regular customer
#
#    avg_spent spender_flag order_frequency
# 0   6.367797  Low spender            20.5
# 1   6.367797  Low spender            20.5
# 2   6.367797  Low spender            20.5
# 3   6.367797  Low spender            20.5
# 4   6.367797  Low spender            20.5
# 5   6.367797  Low spender            20.5
# 6   6.367797  Low spender            20.5
# 7   6.367797  Low spender            20.5
# 8   6.367797  Low spender            20.5
# 9   6.367797  Low spender            20.5
# 10  3.980556  Low spender            10.0
# 11  3.980556  Low spender            10.0
# 12  3.980556  Low spender            10.0
# 13  3.980556  Low spender            10.0
# 14  3.980556  Low spender            10.0
#
# [15 rows x 26 columns]

# %%
#Create flag

df_ords_prods_merge.loc[df_ords_prods_merge['order_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['order_frequency'] <= 20) & (df_ords_prods_merge['order_frequency'] > 10), 'frequency_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['order_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
#Checking output

df_ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: frequency_flag, dtype: int64

# %%
df_ords_prods_merge.head(50)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# 13   2715276       15    prior            21                   1
# 14    487368       15    prior            22                   1
# 15   2293453       19    prior             2                   5
# 16   1973799       19    prior             5                   6
# 17    532817       19    prior             7                   4
# 18   1573906       21    prior            10                   3
# 19   1593000       31    prior            10                   3
# 20   2231262       31    prior            17                   3
# 21   2580647       43    prior             6                   4
# 22   2187180       43    prior             9                   4
# 23   2497897       52    prior             1                   1
# 24   1318871       52    prior             2                   1
# 25   1261384       52    prior             3                   1
# 26    580568       52    prior             5                   2
# 27   2428073       52    prior             7                   2
# 28    342306       52    prior             9                   1
# 29   1520353       52    prior            10                   2
# 30   2542086       52    prior            11                   2
# 31    944694       52    prior            12                   1
# 32   1268191       52    prior            15                   2
# 33   1122089       52    prior            17                   2
# 34   1498922       52    prior            18                   2
# 35    180919       52    prior            19                   3
# 36   2695875       52    prior            21                   5
# 37   3205960       67    prior             1                   3
# 38    970922       67    prior             2                   1
# 39    596585       67    prior             3                   1
# 40   2037087       67    prior             4                   2
# 41   2474111       67    prior             5                   3
# 42   1568481       67    prior             6                   3
# 43   2048527       67    prior             8                   2
# 44   2389031       67    prior             9                   2
# 45   2378562       67    prior            10                   1
# 46   1515698       67    prior            11                   1
# 47   1928050       67    prior            12                   2
# 48   1949274       67    prior            13                   1
# 49    551869       67    prior            14                   1
#
#     order_hour_of_day  days_since_previous_order  new_customer  product_id  \
# 0                   8                        NaN          True         196
# 1                   7                       15.0         False         196
# 2                  12                       21.0         False         196
# 3                   7                       29.0         False         196
# 4                  15                       28.0         False         196
# 5                   7                       19.0         False         196
# 6                   9                       20.0         False         196
# 7                  14                       14.0         False         196
# 8                  16                        0.0         False         196
# 9                   8                       30.0         False         196
# 10                  9                        7.0         False         196
# 11                 16                        8.0         False         196
# 12                 11                        7.0         False         196
# 13                  9                        7.0         False         196
# 14                 10                       14.0         False         196
# 15                 14                        6.0         False         196
# 16                 12                        8.0         False         196
# 17                 17                        6.0         False         196
# 18                 10                        6.0         False         196
# 19                  8                        7.0         False         196
# 20                 11                        8.0         False         196
# 21                 16                        4.0         False         196
# 22                 12                        3.0         False         196
# 23                  9                        NaN          True         196
# 24                 10                        7.0         False         196
# 25                 10                        7.0         False         196
# 26                 10                        8.0         False         196
# 27                  7                        8.0         False         196
# 28                 11                        7.0         False         196
# 29                 10                        8.0         False         196
# 30                  9                        7.0         False         196
# 31                 16                        6.0         False         196
# 32                 11                        8.0         False         196
# 33                 10                        6.0         False         196
# 34                 10                       14.0         False         196
# 35                  8                        8.0         False         196
# 36                 10                       30.0         False         196
# 37                 11                        NaN          True         196
# 38                 15                        5.0         False         196
# 39                 13                        7.0         False         196
# 40                  9                        8.0         False         196
# 41                 14                        8.0         False         196
# 42                 12                        7.0         False         196
# 43                 11                        7.0         False         196
# 44                 14                        7.0         False         196
# 45                 10                        6.0         False         196
# 46                 11                        7.0         False         196
# 47                 12                        8.0         False         196
# 48                 10                        6.0         False         196
# 49                  9                        7.0         False         196
#
#     add_to_cart_order  ...    price_range_loc     busiest_day    busiest_days  \
# 0                   1  ...  Mid-range product  Regularly busy  Regularly busy
# 1                   1  ...  Mid-range product  Regularly busy    Slowest days
# 2                   1  ...  Mid-range product  Regularly busy    Slowest days
# 3                   1  ...  Mid-range product      Least busy    Slowest days
# 4                   1  ...  Mid-range product      Least busy    Slowest days
# 5                   1  ...  Mid-range product  Regularly busy  Regularly busy
# 6                   1  ...  Mid-range product  Regularly busy    Busiest days
# 7                   2  ...  Mid-range product  Regularly busy    Busiest days
# 8                   4  ...  Mid-range product  Regularly busy    Busiest days
# 9                   1  ...  Mid-range product      Least busy    Slowest days
# 10                  2  ...  Mid-range product  Regularly busy    Busiest days
# 11                  6  ...  Mid-range product  Regularly busy  Regularly busy
# 12                  1  ...  Mid-range product  Regularly busy  Regularly busy
# 13                  1  ...  Mid-range product  Regularly busy    Busiest days
# 14                  1  ...  Mid-range product  Regularly busy    Busiest days
# 15                  3  ...  Mid-range product  Regularly busy  Regularly busy
# 16                 15  ...  Mid-range product  Regularly busy  Regularly busy
# 17                  1  ...  Mid-range product      Least busy    Slowest days
# 18                  2  ...  Mid-range product  Regularly busy    Slowest days
# 19                 17  ...  Mid-range product  Regularly busy    Slowest days
# 20                 14  ...  Mid-range product  Regularly busy    Slowest days
# 21                  9  ...  Mid-range product      Least busy    Slowest days
# 22                  1  ...  Mid-range product      Least busy    Slowest days
# 23                  4  ...  Mid-range product  Regularly busy    Busiest days
# 24                  5  ...  Mid-range product  Regularly busy    Busiest days
# 25                  3  ...  Mid-range product  Regularly busy    Busiest days
# 26                  6  ...  Mid-range product  Regularly busy  Regularly busy
# 27                  5  ...  Mid-range product  Regularly busy  Regularly busy
# 28                  5  ...  Mid-range product  Regularly busy    Busiest days
# 29                  4  ...  Mid-range product  Regularly busy  Regularly busy
# 30                  3  ...  Mid-range product  Regularly busy  Regularly busy
# 31                  7  ...  Mid-range product  Regularly busy    Busiest days
# 32                  3  ...  Mid-range product  Regularly busy  Regularly busy
# 33                  4  ...  Mid-range product  Regularly busy  Regularly busy
# 34                  6  ...  Mid-range product  Regularly busy  Regularly busy
# 35                  4  ...  Mid-range product  Regularly busy    Slowest days
# 36                  1  ...  Mid-range product  Regularly busy  Regularly busy
# 37                  1  ...  Mid-range product  Regularly busy    Slowest days
# 38                  2  ...  Mid-range product  Regularly busy    Busiest days
# 39                  2  ...  Mid-range product  Regularly busy    Busiest days
# 40                  1  ...  Mid-range product  Regularly busy  Regularly busy
# 41                  2  ...  Mid-range product  Regularly busy    Slowest days
# 42                  2  ...  Mid-range product  Regularly busy    Slowest days
# 43                  1  ...  Mid-range product  Regularly busy  Regularly busy
# 44                  1  ...  Mid-range product  Regularly busy  Regularly busy
# 45                  1  ...  Mid-range product  Regularly busy    Busiest days
# 46                  1  ...  Mid-range product  Regularly busy    Busiest days
# 47                  1  ...  Mid-range product  Regularly busy  Regularly busy
# 48                  1  ...  Mid-range product  Regularly busy    Busiest days
# 49                  1  ...  Mid-range product  Regularly busy    Busiest days
#
#    busiest_period_of_day  max_order      loyalty_flag  avg_spent spender_flag  \
# 0         Average orders         10      New customer   6.367797  Low spender
# 1         Average orders         10      New customer   6.367797  Low spender
# 2            Most orders         10      New customer   6.367797  Low spender
# 3         Average orders         10      New customer   6.367797  Low spender
# 4            Most orders         10      New customer   6.367797  Low spender
# 5         Average orders         10      New customer   6.367797  Low spender
# 6            Most orders         10      New customer   6.367797  Low spender
# 7            Most orders         10      New customer   6.367797  Low spender
# 8            Most orders         10      New customer   6.367797  Low spender
# 9         Average orders         10      New customer   6.367797  Low spender
# 10           Most orders         22  Regular customer   3.980556  Low spender
# 11           Most orders         22  Regular customer   3.980556  Low spender
# 12           Most orders         22  Regular customer   3.980556  Low spender
# 13           Most orders         22  Regular customer   3.980556  Low spender
# 14           Most orders         22  Regular customer   3.980556  Low spender
# 15           Most orders          9      New customer   8.372059  Low spender
# 16           Most orders          9      New customer   8.372059  Low spender
# 17        Average orders          9      New customer   8.372059  Low spender
# 18           Most orders         33  Regular customer   7.012683  Low spender
# 19        Average orders         20  Regular customer   8.137793  Low spender
# 20           Most orders         20  Regular customer   8.137793  Low spender
# 21           Most orders         11  Regular customer   7.444898  Low spender
# 22           Most orders         11  Regular customer   7.444898  Low spender
# 23           Most orders         27  Regular customer   6.356287  Low spender
# 24           Most orders         27  Regular customer   6.356287  Low spender
# 25           Most orders         27  Regular customer   6.356287  Low spender
# 26           Most orders         27  Regular customer   6.356287  Low spender
# 27        Average orders         27  Regular customer   6.356287  Low spender
# 28           Most orders         27  Regular customer   6.356287  Low spender
# 29           Most orders         27  Regular customer   6.356287  Low spender
# 30           Most orders         27  Regular customer   6.356287  Low spender
# 31           Most orders         27  Regular customer   6.356287  Low spender
# 32           Most orders         27  Regular customer   6.356287  Low spender
# 33           Most orders         27  Regular customer   6.356287  Low spender
# 34           Most orders         27  Regular customer   6.356287  Low spender
# 35        Average orders         27  Regular customer   6.356287  Low spender
# 36           Most orders         27  Regular customer   6.356287  Low spender
# 37           Most orders         24  Regular customer   7.656790  Low spender
# 38           Most orders         24  Regular customer   7.656790  Low spender
# 39           Most orders         24  Regular customer   7.656790  Low spender
# 40           Most orders         24  Regular customer   7.656790  Low spender
# 41           Most orders         24  Regular customer   7.656790  Low spender
# 42           Most orders         24  Regular customer   7.656790  Low spender
# 43           Most orders         24  Regular customer   7.656790  Low spender
# 44           Most orders         24  Regular customer   7.656790  Low spender
# 45           Most orders         24  Regular customer   7.656790  Low spender
# 46           Most orders         24  Regular customer   7.656790  Low spender
# 47           Most orders         24  Regular customer   7.656790  Low spender
# 48           Most orders         24  Regular customer   7.656790  Low spender
# 49           Most orders         24  Regular customer   7.656790  Low spender
#
#    order_frequency         frequency_flag
# 0             20.5  Non-frequent customer
# 1             20.5  Non-frequent customer
# 2             20.5  Non-frequent customer
# 3             20.5  Non-frequent customer
# 4             20.5  Non-frequent customer
# 5             20.5  Non-frequent customer
# 6             20.5  Non-frequent customer
# 7             20.5  Non-frequent customer
# 8             20.5  Non-frequent customer
# 9             20.5  Non-frequent customer
# 10            10.0      Frequent customer
# 11            10.0      Frequent customer
# 12            10.0      Frequent customer
# 13            10.0      Frequent customer
# 14            10.0      Frequent customer
# 15             6.0      Frequent customer
# 16             6.0      Frequent customer
# 17             6.0      Frequent customer
# 18             7.5      Frequent customer
# 19             6.0      Frequent customer
# 20             6.0      Frequent customer
# 21            10.0      Frequent customer
# 22            10.0      Frequent customer
# 23             8.0      Frequent customer
# 24             8.0      Frequent customer
# 25             8.0      Frequent customer
# 26             8.0      Frequent customer
# 27             8.0      Frequent customer
# 28             8.0      Frequent customer
# 29             8.0      Frequent customer
# 30             8.0      Frequent customer
# 31             8.0      Frequent customer
# 32             8.0      Frequent customer
# 33             8.0      Frequent customer
# 34             8.0      Frequent customer
# 35             8.0      Frequent customer
# 36             8.0      Frequent customer
# 37             7.0      Frequent customer
# 38             7.0      Frequent customer
# 39             7.0      Frequent customer
# 40             7.0      Frequent customer
# 41             7.0      Frequent customer
# 42             7.0      Frequent customer
# 43             7.0      Frequent customer
# 44             7.0      Frequent customer
# 45             7.0      Frequent customer
# 46             7.0      Frequent customer
# 47             7.0      Frequent customer
# 48             7.0      Frequent customer
# 49             7.0      Frequent customer
#
# [50 rows x 27 columns]

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 27)

# %% [markdown]
# ## 08. Dealing with Memory Issues

# %%
df_ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_previous_order', 'new_customer',
#        'product_id', 'add_to_cart_order', 'reordered', '_merge', 'Unnamed: 0',
#        'product_name', 'aisle_id', 'department_id', 'prices',
#        'price_range_loc', 'busiest_day', 'busiest_days',
#        'busiest_period_of_day', 'max_order', 'loyalty_flag', 'avg_spent',
#        'spender_flag', 'order_frequency', 'frequency_flag'],
#       dtype='object')

# %%
df_ords_prods_merge.drop(columns = {'eval_set', 'Unnamed: 0', 'busiest_day'}, inplace = True)

# %%
df_ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_previous_order', 'new_customer',
#        'product_id', 'add_to_cart_order', 'reordered', '_merge',
#        'product_name', 'aisle_id', 'department_id', 'prices',
#        'price_range_loc', 'busiest_days', 'busiest_period_of_day', 'max_order',
#        'loyalty_flag', 'avg_spent', 'spender_flag', 'order_frequency',
#        'frequency_flag'],
#       dtype='object')

# %%
df_ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 24 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   order_id                   int64
#  1   user_id                    int64
#  2   order_number               int64
#  3   orders_day_of_week         int64
#  4   order_hour_of_day          int64
#  5   days_since_previous_order  float64
#  6   new_customer               bool
#  7   product_id                 int64
#  8   add_to_cart_order          int64
#  9   reordered                  int64
#  10  _merge                     category
#  11  product_name               object
#  12  aisle_id                   int64
#  13  department_id              int64
#  14  prices                     float64
#  15  price_range_loc            object
#  16  busiest_days               object
#  17  busiest_period_of_day      object
#  18  max_order                  int64
#  19  loyalty_flag               object
#  20  avg_spent                  float64
#  21  spender_flag               object
#  22  order_frequency            float64
#  23  frequency_flag             object
# dtypes: bool(1), category(1), float64(4), int64(11), object(7)
# memory usage: 5.6+ GB

# %%
#Change types for data set

df_ords_prods_merge['order_id']=df_ords_prods_merge['order_id'].astype('int32')
df_ords_prods_merge['user_id'] = df_ords_prods_merge['user_id'].astype('int32')
df_ords_prods_merge['order_number']=df_ords_prods_merge['order_number'].astype('int8')
df_ords_prods_merge['orders_day_of_week']=df_ords_prods_merge['orders_day_of_week'].astype('int8')
df_ords_prods_merge['order_hour_of_day']=df_ords_prods_merge['order_hour_of_day'].astype('int8')
df_ords_prods_merge['days_since_previous_order']=df_ords_prods_merge['days_since_previous_order'].astype('float16')
df_ords_prods_merge['product_id'] =df_ords_prods_merge['product_id'].astype('int32')
df_ords_prods_merge['reordered']=df_ords_prods_merge['reordered'].astype('int8')
df_ords_prods_merge['add_to_cart_order']=df_ords_prods_merge['add_to_cart_order'].astype('int32')
df_ords_prods_merge['aisle_id'] = df_ords_prods_merge['aisle_id'].astype('int8')
df_ords_prods_merge['department_id'] = df_ords_prods_merge['department_id'].astype('int8')
df_ords_prods_merge['prices'] = df_ords_prods_merge['prices'].astype('float16')

# %%
df_ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 24 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   order_id                   int32
#  1   user_id                    int32
#  2   order_number               int8
#  3   orders_day_of_week         int8
#  4   order_hour_of_day          int8
#  5   days_since_previous_order  float16
#  6   new_customer               bool
#  7   product_id                 int32
#  8   add_to_cart_order          int32
#  9   reordered                  int8
#  10  _merge                     category
#  11  product_name               object
#  12  aisle_id                   int8
#  13  department_id              int8
#  14  prices                     float16
#  15  price_range_loc            object
#  16  busiest_days               object
#  17  busiest_period_of_day      object
#  18  max_order                  int64
#  19  loyalty_flag               object
#  20  avg_spent                  float64
#  21  spender_flag               object
#  22  order_frequency            float64
#  23  frequency_flag             object
# dtypes: bool(1), category(1), float16(2), float64(2), int32(4), int64(1), int8(6), object(7)
# memory usage: 3.5+ GB

# %% [markdown]
# ## 09. Extracting Data

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged_v3.pkl'))

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_previous_order  new_customer  product_id  add_to_cart_order  \
# 0                        NaN          True         196                  1
# 1                       15.0         False         196                  1
# 2                       21.0         False         196                  1
# 3                       29.0         False         196                  1
# 4                       28.0         False         196                  1
#
#    reordered  ... prices    price_range_loc    busiest_days  \
# 0          0  ...    9.0  Mid-range product  Regularly busy
# 1          1  ...    9.0  Mid-range product    Slowest days
# 2          1  ...    9.0  Mid-range product    Slowest days
# 3          1  ...    9.0  Mid-range product    Slowest days
# 4          1  ...    9.0  Mid-range product    Slowest days
#
#    busiest_period_of_day  max_order  loyalty_flag avg_spent spender_flag  \
# 0         Average orders         10  New customer  6.367797  Low spender
# 1         Average orders         10  New customer  6.367797  Low spender
# 2            Most orders         10  New customer  6.367797  Low spender
# 3         Average orders         10  New customer  6.367797  Low spender
# 4            Most orders         10  New customer  6.367797  Low spender
#
#    order_frequency         frequency_flag
# 0             20.5  Non-frequent customer
# 1             20.5  Non-frequent customer
# 2             20.5  Non-frequent customer
# 3             20.5  Non-frequent customer
# 4             20.5  Non-frequent customer
#
# [5 rows x 24 columns]
